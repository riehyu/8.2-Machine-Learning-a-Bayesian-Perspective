# %% [markdown]
# Install necessary dependencies

# %%
# !pip install torch
# !pip install tqdm
# !pip install Pillow
# !pip install matplotlib
# !pip install dominate
# !pip install wandb
# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install "numpy<2"
# Out:
# Running cells with '.venv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/riehyu/Downloads/Ass8_2 2/.venv/bin/python" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# Checking if GPU is usable (Only for local running checks, in the report we used with the TU Delfts remote GPU connection borrowed by professor)

# %%
import torch
print(torch.cuda.is_available())  
print(torch.cuda.get_device_name(0))
print(torch.cuda.device_count())
for i in range (torch.cuda.device_count()):
    print(f"GPU {i}:{torch.cuda.get_device_name(i)}")

import torch.nn as nn
# Out:
# True
# NVIDIA GeForce RTX 3050 6GB Laptop GPU
# 1
# GPU 0:NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# This is for splitting data into 8:2

# %%
# !ls datasets/dataset/photo_jpg/ | head -5622 | xargs -I{} cp datasets/dataset/photo_jpg/{} datasets/monet2photo/trainA/

# !ls datasets/dataset/photo_jpg/ | tail -n +5623 | xargs -I{} cp datasets/dataset/photo_jpg/{} datasets/monet2photo/testA/

# !ls datasets/dataset/monet_jpg/ | head -240 | xargs -I{} cp datasets/dataset/monet_jpg/{} datasets/monet2photo/trainB/

# !ls datasets/dataset/monet_jpg/ | tail -n +241 | xargs -I{} cp datasets/dataset/monet_jpg/{} datasets/monet2photo/testB/

# %% [markdown]
# Check if the data set is splitted correctly

# %%
# !echo "trainA:" $(ls datasets/monet2photo/trainA | wc -l)
# !echo "testA:" $(ls datasets/monet2photo/testA | wc -l)
# !echo "trainB:" $(ls datasets/monet2photo/trainB | wc -l)
# !echo "testB:" $(ls datasets/monet2photo/testB | wc -l)
# Out:
# trainA: 5622
# testA: 1416
# trainB: 240
# testB: 60

# %% [markdown]
# Redirect to the right path

# %%
import os
os.chdir('/Users/riehyu/Downloads/Ass8_2 2/pytorch-CycleGAN-and-pix2pix')
print(os.getcwd())
# Out:
# /Users/riehyu/Downloads/Ass8_2 2/pytorch-CycleGAN-and-pix2pix

# %%
os.environ["WANDB_API_KEY"] = "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"

# %%
# !torchrun --nproc_per_node=4 train.py --dataroot ./datasets/monet2photo \
                 --name monet2photo \
                 --model cycle_gan \
                 --batch_size 4 \
                 --n_epochs 20 \
                 --n_epochs_decay 20 \
                 --no_html \
                 --use_wandb \
                 --wandb_project_name monet2photo_cyclegan
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/monet2photo        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#              display_freq: 400
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
# ...

# %%
# !python test.py \
--dataroot ./datasets/monet2photo \
--name monet2photo \
--model cycle_gan \
--phase test \
--batch_size 1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/monet2photo        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: monet2photo                   	[default: experiment_name]
#                       ndf: 64
# ...
